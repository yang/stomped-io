# %%
import re, itertools as itr, collections as col, pandas as pd, langdetect, io

# %%
with io.open('bounce.log', encoding='utf8') as f: contents = f.read()

# %%
pat = re.compile(r"""'player' '(.+?) \(\d+?\)' 'with style' '(.+?)' 'joined \(client (\d+?)\)'""")
def joins():
    for m in pat.finditer(contents):
        name, sty, cli = m.groups()
        yield cli, name, sty

# %% [markdown]
# # Popular characters

# %%
def rank_chars():
    for cli, group in itr.groupby(sorted(joins()), key=lambda (cli, name, sty): cli):
        [(pop_sty, count)] = col.Counter(sty for cli, name, sty in group).most_common(1)
        yield cli, pop_sty
col.Counter(sty for cli, sty in rank_chars()).most_common(99)
# Out:
# [('robot-0', 3964),
#  ('alien-0', 3007),
#  ('spacesuit-0', 2853),
#  ('plumber-0', 2736),
#  ('plain-1', 2604),
#  ('robot-2', 2101),
#  ('spacesuit-1', 2009),
#  ('plain-0', 1961),
#  ('skeleton-2', 1732),
#  ('plain-2', 1702),
#  ('skeleton-0', 1499),
#  ('alien-2', 1332),
#  ('spacesuit-2', 1237),
#  ('skeleton-1', 1165),
#  ('robot-1', 1155),
#  ('plumber-2', 1086),
#  ('plumber-1', 910),
#  ('alien-1', 415),
#  ('reddit-0', 199),
#  ('slender-0', 42)]

# %% [markdown]
# # Repeat plays

# %%
cli2nplays = col.Counter(cli for cli, name, sty in joins())
df = pd.DataFrame(cli2nplays.items(), columns=['cli','nplays'])
df.describe()
# Out:
#              nplays
# count  33709.000000
# mean       3.999852
# std        6.450676
# min        1.000000
# 25%        1.000000
# 50%        1.000000
# 75%        4.000000
# max       89.000000

# %%
col.Counter((cli, name) for cli, name, sty in joins()).most_common(30)
# Out:
# [(('7426885', 'baymax'), 89),
#  (('2094240', 'DAMIAM'), 82),
#  (('10486048', 'LUKY'), 71),
#  (('3329323', 'noob'), 68),
#  (('742933', '...'), 68),
#  (('1882289', 'Anonymous Stomper'), 67),
#  (('7653037', "Don\\'t try it Anakin"), 62),
#  (('4563954', '???'), 62),
#  (('8032635', 'ROEI'), 59),
#  (('4245337', 'vn?'), 59),
#  (('10675306', 'theskullguy158'), 58),
#  (('1561197', 'vegito'), 58),
#  (('369703', 'Lance12'), 58),
#  (('6297726', 'smasher'), 58),
#  (('6373959', 'tgghgtgfggf'), 57),
#  (('6180800', 'lol'), 57),
#  (('12374220', "Don\\'t try it Anakin!"), 54),
#  (('5181027', 'a'), 53),
#  (('342902', 'uio'), 52),
#  (('45511', 'lolol'), 52),
#  (('913071', 'foxy'), 51),
#  (('9027453', 'ATH'), 51),
#  (('10783722', 'yo'), 50),
#  (('6327197', 'sans'), 50),
#  (('2011985', 'ytutfk'), 50),
#  (('1067262', 'Tristan Man'), 50),
#  (('477637', 'destroyer'), 50),
#  (('6209360', 'king of north'), 50),
#  (('2531840', 'fk you'), 50),
#  (('6665971', 'bnb'), 50)]

# %% [markdown]
# # Names / Repeat Visitors

# %%
name_freq = col.Counter(name for cli, name in {(cli, name) for cli, name, sty in joins()})
name_freq.most_common(30)
# Out:
# [(u'lol', 416),
#  (u'hi', 353),
#  (u'mario', 256),
#  (u'Mario', 160),
#  (u'a', 117),
#  (u'paku.io', 108),
#  (u'juan', 99),
#  (u'123', 94),
#  (u'asd', 91),
#  (u'gg', 86),
#  (u'1', 85),
#  (u'bob', 84),
#  (u'f', 74),
#  (u'hola', 71),
#  (u'deathviper79', 71),
#  (u'noob', 69),
#  (u'g', 67),
#  (u'pop', 64),
#  (u'yourself', 63),
#  (u'd', 62),
#  (u'Luigi', 61),
#  (u'alex', 59),
#  (u's', 57),
#  (u'damiam', 54),
#  (u'box', 54),
#  (u'eryh', 53),
#  (u'io', 53),
#  (u'j', 53),
#  (u'h', 52),
#  (u'HI', 50)]

# %% [markdown]
# # Special name searches

# %%
lower_name_freq = col.Counter()
for name, count in name_freq.items():
    lower_name_freq[name.lower()] = lower_name_freq.get(name.lower(), 0) + count
names = '''
fady
paku.io
markiplier
pewdiepie
jacksepticeye
kwebblekop
'''.split()
[(name, lower_name_freq.get(name)) for name in names]
# Out:
# [('fady', 83),
#  ('paku.io', 111),
#  ('markiplier', 3),
#  ('pewdiepie', 1),
#  ('jacksepticeye', None),
#  ('kwebblekop', 2)]

# %% [markdown]
# # Name regions

# %%
def try_detect(name):
    try: return langdetect.detect(name)
    except: return ''
lang2names = {}
for name in name_freq:
    lang = try_detect(name)
    lang2names.setdefault(lang, []).append(name)
# Out:
# 1456 en
# death...from...above
# The Worst
# eshea
# MOSHE REAPER!!!!!!!!!!!!!!!!!!!!
# im.new.dont.atack.me
# My name is Jeef\'s
# I am the one
# but did NOT stomp that guy
# IT IS ME MAREO
# athal
#
# 1265 cy
# ytdefb
# Mr.Joey
# hfghfgt
# dqsdysu
# g4h35b4
# r66
# ethan-.,.269-yulio
# rgdfg
# pawel
# gthyyy7ui
#
# 1224 de
# ULTRA ZERG
# kdfhnfghsdfhd
# BLAHBLAHHHHHHHHHHHHHHHHHHHHHHHHH
# DSFDSFDSFFD
# FJHSALKGEJHSLKGJ
# BEN
# thunder
# herb
# Dick Kickem
# SMDC
#
# 1001 so
# daynis
# oooh
# o oooo
# yeerk
# lrrkwqwl
# baymax
# vaaaaaaaaaaaaaddajbhf
# WARIO!
# darkwood
# hidalgo
#
# 795 tl
# no kill
# antip2010
# Bayonetta
# pato
# gg\\
# agirl
# ysysgkayxuv
# A
# sasasa
# ALEIN
#
# 783 sw
# hjikig
# MUAHAHAHAHAHAHAHAHAHAHAHAHAHAHAH
# MSJHGFIUHFDUIJGHR
# k
# MIGIT
# want
# 7uyjhjhuy
# Hia
# samuzao
# wales
#
# 688
# (0_0)(0_0)
# [
# 88888888888888888888888888888
# 9+
# 224522203
# 98
# ｔ
# 111111111111111
# 1000
# 55546654
#
# 603 fi
# luis y mami
# Rafael fakkkkkkkkkkkkkkkkkkkkkkk
# Trissitan
# aishmarjuliethc
# LittyTitties
# ona_777
# axtronautita Blanko
# osin
# sssssssssssss
# JustSkill
#
# 597 id
# Sugar
# Seberstjan
# Kman
# Jumper
# ILYAS
# SkupaCZ
# Mar.IO
# BDPanda
# ian
# JCRFH
#
# 560 it
# dcc
# Felipe
# Necati!
# ricardo_11
# ;;;.;lllllllllllllllll
# pinto
# cipa
# carnom
# Millennium falcon
# Titanfall
#
# 514 da
# slenderman
# nigger
# golden
# dbn
# sdfgdsfa
# dssffvd
# fghj
# nigger faggot
# dgg
# dsf
#
# 512 ru
# 173856994807нгшоо
# миыпвпа
# симён
# мавп
# ммм жопец
# смм
# ооллрррррррррррррррррррррррррррр
# убийца
# апас
# ВФ
#
# 472 pl
# wwwscfv
# Zesty
# dczc
# fryzuras
# nick PL
# PolicierDu57
# zayne
# lego
# Honyp
# rycekake
#
# 455 vi
# xtc
# NON
# HLG
# NOPE
# Turgon
# THEREALDANTDM
# huy hung
# hjguyg
# tg4t
# anh
#
# 426 es
# GalacticTacoYT
# Chillieguy
# dragon lord
# lord
# EDU
# el matador 7
# Alíen 2.0
# EQUELETO
# soy un robot
# cesar
#
# 410 pt
# mario\\
# do+´\'s
# Cosmo55
# doru
# dora
# ummamed
# CaRtOoNz
# JJuloPro
# MILLO64
# AAAASHSHSHSH OOOO TTTT
#
# 388 ro
# gui  123
# Mortex
# Reponix
# culo
# Audi
# fiu
# re
# murilo
# mlopuiil
# RYRUR68RR66I9
#
# 359 et
# gujuu
# möööööööööööööööööööö2
# riplilpeep
# lolek
# jhguhb
# lolilol
# tolga
# miig
# Luigi >:V
# jooooll
#
# 359 af
# ooof
# asdsw
# ewa
# eww      dsfsf  dsf wse fdf re e
# Daan IS PRO
# ink sans
# NRTRwater
# niebe
# Jesie
# woei
#
# 354 nl
# hero
# Neander
# regele
# coolweegee
# ghghjjnm
# egemen
# dogepl
# mee
# uioi
# eeeeeeeeeeeeeeeeee
#
# 351 sq
# kțkțgtetjt4
# emir
# ohshit
# gjrbhdleșfksckhjdhjshsbnnxnrrr5j
# hj12
# rr
# ptptpt
# ahmet
# khkhkhhmjmmmbmhnjh
# Nike Air
#
# 349 no
# melvin
# tette6r5<4
# andrew rannells
# I my me mine
# ssundde
# melone
# sneider
# bubbles
# silver
# skellatron1000
#
# 331 fr
# coucou
# LEGO
# LEON
# LEOX
# Lo
# LO
# your mom!
# Lolxd
# rt
# auê
#
# 313 sl
# kijàjjà_jçuhu
# favij
# dejez
# skillz
# nepe
# rj
# jajajajajajajajajameparto
# jhkj
# parejo
# sok
#
# 301 hr
# dgdjlu;
# IamLiz040\\
# jamjar
# Anička
# drgyujkg
# iu9u9u
# hi im nice
# jeris
# blazetron
# ra
#
# 275 sv
# jk\'jhgdsdgfjhklhgfdsxgchjbknml
# andro
# gharet
# sssssdsdsdsd
# G4atav6
# Rocket Man
# klm,.6
# Carsonsd
# kppppppppppppppppppppppppúpppppp
# YouHacker
#
# 273 sk
# tovblv::cr
# dick name
# suck my ......
# 6 Uru UT FYI jet giusto try huff
# ho
# mohod
# ro
# maverick
# cfv vvgb
# j/a
#
# 266 tr
# Merlin
# debil
# DonutDayzy
# Ada
# Türküm
# lil yeze
# 💓 Hitler 💓
# uyui
# ıo
# karim-6
#
# 263 lt
# jose.67
# ?m?
# tinyrobot
# ambriš
# Kumagai Saki japonais
# aurora\'s mom
# pirte
# austronauta
# sram
# vaid
#
# 253 ca
# txtval#*##|#ctl00_cDM_cF_0t#*#5#
# txt
# l-----------------l
# ANSE,L
# ~l /
# lacra
# reydeitaca 189
# PixelHero
# miguel angel
# Prx
#
# 245 mk
# папнап
# вилд
# Владик
# апап
# иш
# еапавп
# црваип
# пози
# тим
# лапа
#
# 240 hu
# fbbghdjfg
# zhe yokoso
# a kid
# Bazdmeg
# azereus
# Egg
# Bartosz3000
# legs
# zssz
# dhazzel
#
# 200 bg
# сми
# полина
# ОЬТРРПЬМСЬ
# дима
# КИРИЛЛ
# фидан
# ЕРТИТТТИЬИТ Т ТТЬТ ТЬТТТ ЬИИОЬ Т
# ЕРШАТ
# дан  дар
# Ярик
#
# 192 uk
# й2уйцуц
# ШГЩ
# НЕКИТ
# батя рп 12341
# цйфцв
# яищнттхсмвддвмтсднндз
# 987р65пк
# УКЕЕННГГШ51235678
# уйуй
# УЦВ
#
# 161 cs
# chcípni
# bvhjgtvyk
# c-u-v-o-  .i
# hů.gphpgpfpgouziuohů,
# jhbvy
# jaco
# snickname
# gruytvcnbbvc v
# Blocky
# zxftu907
#
# 115 lv
# vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
# sasd
# smp
# iro
# ire
# piotr
# sdas
# vika
# jgs
# jasper
#
# 95 ar
# سصثقé"ث"éثéث
# اةتنؤ
# ظمظكمظكنةمت
# بلفففقاقفاقف(لافقافقالفقا
# ثنا
# طارق
# ال
# العاب بطل
# شطر بطر
# مصطفى
#
# 62 ja
# さかつば
# さくら
# ぬるぽ
# マリオ一
# ひといきゲーム
# はいはい
# おっぱい飲んだよ！
# マインクラフト
# こころ
# あ
#
# 45 th
# ฮษโศโฯ็ฌ
# ไทย
# กดเดกเ
# ้่้่
# ขี้หี
# 787484774า่า่รรค่ร่ึรีึัุึรร้คี่
# ฎฑโฎ
# ภดพำเอำ
# คิม
# อีเหี้ยออย
#
# 21 el
# νξβξωνμηζξμχηζσθηψξκ
# ερυτυτυγφηξ\\
# ๖ۣۜǤнσsτ༻一�:
# ερυτυτυ
# ερυτυτυγφηξασασρφδτττωφτγ\\
# ҜίĻĻᗴŘ
# ΚΩΣΤα
# φγφ
# ｇｇ((」’ω’)」ｵｫｵｫｵ!!!ｳｳｩｩｱｱｫｵ!!!!!!
# αζσςδφξ100200
#
# 19 ko
# 씨박녕
# 安安
# 煎茶
# 神
# 謝秉澤
# 粗
# 太郎
# 持
# 878發明家
# 升垃
#
# 13 fa
# بر
# وونزونمنزمزمنمزمزمزم
# ىهتنخههخنه
# سيرين
# سيرين  بيوض
# ياسمين
# زمين
# ززممزمزمزز
# ادم
# \\تا
#
# 7 zh-cn
# ；；；
# 大家
# [日本]
# ·········
# 人在哥廢物
# 更木劍八
# ：）
#
# 6 he
# שלום
# שירי
# \'/ר\'
# איה בארי= מנשה
# מנשה
# בולי
#
# 5 ur
# طرطبظب
# رياض
# عظم
# ي
# جرجس
#
# 2 kn
# (╭☞ಠᴥಠ)╭☞
# ಠ_ಠ
#
# 1 zh-tw
# 哥來囉
#
# 1 bn
# ▁▂▃▄▅▆▇█▓▒▓⇉�⇇▒▓▒█▇▆▅▄▃▂▁

# %%
groupings = [(len(names), lang, names) for lang, names in lang2names.items()]
for a, b, cs in list(reversed(sorted(groupings)))[:100]:
    print a,b
    for c in cs[:10]:
        print c
    print
# Out:
# 1456 en
# death...from...above
# The Worst
# eshea
# MOSHE REAPER!!!!!!!!!!!!!!!!!!!!
# im.new.dont.atack.me
# My name is Jeef\'s
# I am the one
# but did NOT stomp that guy
# IT IS ME MAREO
# athal
#
# 1265 cy
# ytdefb
# Mr.Joey
# hfghfgt
# dqsdysu
# g4h35b4
# r66
# ethan-.,.269-yulio
# rgdfg
# pawel
# gthyyy7ui
#
# 1224 de
# ULTRA ZERG
# kdfhnfghsdfhd
# BLAHBLAHHHHHHHHHHHHHHHHHHHHHHHHH
# DSFDSFDSFFD
# FJHSALKGEJHSLKGJ
# BEN
# thunder
# herb
# Dick Kickem
# SMDC
#
# 1001 so
# daynis
# oooh
# o oooo
# yeerk
# lrrkwqwl
# baymax
# vaaaaaaaaaaaaaddajbhf
# WARIO!
# darkwood
# hidalgo
#
# 795 tl
# no kill
# antip2010
# Bayonetta
# pato
# gg\\
# agirl
# ysysgkayxuv
# A
# sasasa
# ALEIN
#
# 783 sw
# hjikig
# MUAHAHAHAHAHAHAHAHAHAHAHAHAHAHAH
# MSJHGFIUHFDUIJGHR
# k
# MIGIT
# want
# 7uyjhjhuy
# Hia
# samuzao
# wales
#
# 688
# (0_0)(0_0)
# [
# 88888888888888888888888888888
# 9+
# 224522203
# 98
# ｔ
# 111111111111111
# 1000
# 55546654
#
# 603 fi
# luis y mami
# Rafael fakkkkkkkkkkkkkkkkkkkkkkk
# Trissitan
# aishmarjuliethc
# LittyTitties
# ona_777
# axtronautita Blanko
# osin
# sssssssssssss
# JustSkill
#
# 597 id
# Sugar
# Seberstjan
# Kman
# Jumper
# ILYAS
# SkupaCZ
# Mar.IO
# BDPanda
# ian
# JCRFH
#
# 560 it
# dcc
# Felipe
# Necati!
# ricardo_11
# ;;;.;lllllllllllllllll
# pinto
# cipa
# carnom
# Millennium falcon
# Titanfall
#
# 514 da
# slenderman
# nigger
# golden
# dbn
# sdfgdsfa
# dssffvd
# fghj
# nigger faggot
# dgg
# dsf
#
# 512 ru
# 173856994807нгшоо
# миыпвпа
# симён
# мавп
# ммм жопец
# смм
# ооллрррррррррррррррррррррррррррр
# убийца
# апас
# ВФ
#
# 472 pl
# wwwscfv
# Zesty
# dczc
# fryzuras
# nick PL
# PolicierDu57
# zayne
# lego
# Honyp
# rycekake
#
# 455 vi
# xtc
# NON
# HLG
# NOPE
# Turgon
# THEREALDANTDM
# huy hung
# hjguyg
# tg4t
# anh
#
# 426 es
# GalacticTacoYT
# Chillieguy
# dragon lord
# lord
# EDU
# el matador 7
# Alíen 2.0
# EQUELETO
# soy un robot
# cesar
#
# 410 pt
# mario\\
# do+´\'s
# Cosmo55
# doru
# dora
# ummamed
# CaRtOoNz
# JJuloPro
# MILLO64
# AAAASHSHSHSH OOOO TTTT
#
# 388 ro
# gui  123
# Mortex
# Reponix
# culo
# Audi
# fiu
# re
# murilo
# mlopuiil
# RYRUR68RR66I9
#
# 359 et
# gujuu
# möööööööööööööööööööö2
# riplilpeep
# lolek
# jhguhb
# lolilol
# tolga
# miig
# Luigi >:V
# jooooll
#
# 359 af
# ooof
# asdsw
# ewa
# eww      dsfsf  dsf wse fdf re e
# Daan IS PRO
# ink sans
# NRTRwater
# niebe
# Jesie
# woei
#
# 354 nl
# hero
# Neander
# regele
# coolweegee
# ghghjjnm
# egemen
# dogepl
# mee
# uioi
# eeeeeeeeeeeeeeeeee
#
# 351 sq
# kțkțgtetjt4
# emir
# ohshit
# gjrbhdleșfksckhjdhjshsbnnxnrrr5j
# hj12
# rr
# ptptpt
# ahmet
# khkhkhhmjmmmbmhnjh
# Nike Air
#
# 349 no
# melvin
# tette6r5<4
# andrew rannells
# I my me mine
# ssundde
# melone
# sneider
# bubbles
# silver
# skellatron1000
#
# 331 fr
# coucou
# LEGO
# LEON
# LEOX
# Lo
# LO
# your mom!
# Lolxd
# rt
# auê
#
# 313 sl
# kijàjjà_jçuhu
# favij
# dejez
# skillz
# nepe
# rj
# jajajajajajajajajameparto
# jhkj
# parejo
# sok
#
# 301 hr
# dgdjlu;
# IamLiz040\\
# jamjar
# Anička
# drgyujkg
# iu9u9u
# hi im nice
# jeris
# blazetron
# ra
#
# 275 sv
# jk\'jhgdsdgfjhklhgfdsxgchjbknml
# andro
# gharet
# sssssdsdsdsd
# G4atav6
# Rocket Man
# klm,.6
# Carsonsd
# kppppppppppppppppppppppppúpppppp
# YouHacker
#
# 273 sk
# tovblv::cr
# dick name
# suck my ......
# 6 Uru UT FYI jet giusto try huff
# ho
# mohod
# ro
# maverick
# cfv vvgb
# j/a
#
# 266 tr
# Merlin
# debil
# DonutDayzy
# Ada
# Türküm
# lil yeze
# 💓 Hitler 💓
# uyui
# ıo
# karim-6
#
# 263 lt
# jose.67
# ?m?
# tinyrobot
# ambriš
# Kumagai Saki japonais
# aurora\'s mom
# pirte
# austronauta
# sram
# vaid
#
# 253 ca
# txtval#*##|#ctl00_cDM_cF_0t#*#5#
# txt
# l-----------------l
# ANSE,L
# ~l /
# lacra
# reydeitaca 189
# PixelHero
# miguel angel
# Prx
#
# 245 mk
# папнап
# вилд
# Владик
# апап
# иш
# еапавп
# црваип
# пози
# тим
# лапа
#
# 240 hu
# fbbghdjfg
# zhe yokoso
# a kid
# Bazdmeg
# azereus
# Egg
# Bartosz3000
# legs
# zssz
# dhazzel
#
# 200 bg
# сми
# полина
# ОЬТРРПЬМСЬ
# дима
# КИРИЛЛ
# фидан
# ЕРТИТТТИЬИТ Т ТТЬТ ТЬТТТ ЬИИОЬ Т
# ЕРШАТ
# дан  дар
# Ярик
#
# 192 uk
# й2уйцуц
# ШГЩ
# НЕКИТ
# батя рп 12341
# цйфцв
# яищнттхсмвддвмтсднндз
# 987р65пк
# УКЕЕННГГШ51235678
# уйуй
# УЦВ
#
# 161 cs
# chcípni
# bvhjgtvyk
# c-u-v-o-  .i
# hů.gphpgpfpgouziuohů,
# jhbvy
# jaco
# snickname
# gruytvcnbbvc v
# Blocky
# zxftu907
#
# 115 lv
# vvvvvvvvvvvvvvvvvvvvvvvvvvvvvvvv
# sasd
# smp
# iro
# ire
# piotr
# sdas
# vika
# jgs
# jasper
#
# 95 ar
# سصثقé"ث"éثéث
# اةتنؤ
# ظمظكمظكنةمت
# بلفففقاقفاقف(لافقافقالفقا
# ثنا
# طارق
# ال
# العاب بطل
# شطر بطر
# مصطفى
#
# 62 ja
# さかつば
# さくら
# ぬるぽ
# マリオ一
# ひといきゲーム
# はいはい
# おっぱい飲んだよ！
# マインクラフト
# こころ
# あ
#
# 45 th
# ฮษโศโฯ็ฌ
# ไทย
# กดเดกเ
# ้่้่
# ขี้หี
# 787484774า่า่รรค่ร่ึรีึัุึรร้คี่
# ฎฑโฎ
# ภดพำเอำ
# คิม
# อีเหี้ยออย
#
# 21 el
# νξβξωνμηζξμχηζσθηψξκ
# ερυτυτυγφηξ\\
# ๖ۣۜǤнσsτ༻一�:
# ερυτυτυ
# ερυτυτυγφηξασασρφδτττωφτγ\\
# ҜίĻĻᗴŘ
# ΚΩΣΤα
# φγφ
# ｇｇ((」’ω’)」ｵｫｵｫｵ!!!ｳｳｩｩｱｱｫｵ!!!!!!
# αζσςδφξ100200
#
# 19 ko
# 씨박녕
# 安安
# 煎茶
# 神
# 謝秉澤
# 粗
# 太郎
# 持
# 878發明家
# 升垃
#
# 13 fa
# بر
# وونزونمنزمزمنمزمزمزم
# ىهتنخههخنه
# سيرين
# سيرين  بيوض
# ياسمين
# زمين
# ززممزمزمزز
# ادم
# \\تا
#
# 7 zh-cn
# ；；；
# 大家
# [日本]
# ·········
# 人在哥廢物
# 更木劍八
# ：）
#
# 6 he
# שלום
# שירי
# \'/ר\'
# איה בארי= מנשה
# מנשה
# בולי
#
# 5 ur
# طرطبظب
# رياض
# عظم
# ي
# جرجس
#
# 2 kn
# (╭☞ಠᴥಠ)╭☞
# ಠ_ಠ
#
# 1 zh-tw
# 哥來囉
#
# 1 bn
# ▁▂▃▄▅▆▇█▓▒▓⇉�⇇▒▓▒█▇▆▅▄▃▂▁
